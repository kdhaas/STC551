# %% [markdown]
# # Descriptive Stastics in Python Exercise - Module 1
#
# In this exercise we will use a dataset related to a collection of individual fundraising campaigns created via the [GoFundMe](https://gofundme.com) website. The data comes from a [project on Github](https://github.com/lmeninato/GoFundMe/) which collected information about GoFundMe projects in 2018.
#
# You will apply your knowledge of descriptive stastics and skills from the data wrangling course to summarize information about specific categories of projects. I've stubbed out a series of steps below. I will describe each task and leave an open code block for you to complete the task. Please use text blocks to summarize your analysis. Use your own knowledge and the [Module 1 example descriptive stats notebook](https://github.com/digitalshawn/STC551/blob/main/Module%201/Descriptive%20Stats%20Example.ipynb) as a guide, but you may use other techniques to answer the prompts.
#
# ## What to submit via Canvas
#
# Download a copy of your completed notebook from Google Colab (File --> Download --> Download .ipynb) and upload it to Canvas for this assignment. Please make sure that you run all code blocks so I can see the output when I open the notebook file.
#
# ## Help! I have questions!
#
# You may email me with questions or ask to setup a Zoom meeting so we can look at your code together. You may also use the Canvas discussion board to ask questions and share tips. While I ask that you do not collaborate on answers, you may discuss the assignment via Canvas. Keeping any discussions public allows everyone to benefit!

# %% [markdown]
# # Let's Get Started!
#
# ### Task hints
#
# *   `instructions in this style require you to write and execute python code in a code block`
# *   instructions in this style require you to write a summary, analysis, or explanation in a text block
#
#
#
#
# Here we load the modules we will use in this script. They are the same modules that are used in the [example notebook](https://github.com/digitalshawn/STC551/blob/main/Module%201/Descriptive%20Stats%20Example.ipynb).

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px # accessible module for plotting graphs
from scipy.stats import skew, kurtosis # to analyze the skew of our dataset
import plotly.figure_factory as ff

# %% [markdown]
# # Loading the GoFundMe Data
#
# Below we load the GoFundMe data directly via its GitHub URL. Briefly take a look [at the data file](https://raw.githubusercontent.com/lmeninato/GoFundMe/master/data-raw/GFM_data.csv). You'll see that although the files ends in .csv, the fields are delimited (seperated) via a tab and not a comma. You'll see that I've flagged this for panda's read_csv() function using the `sep` argument and setting it equal to a tab (`\t`).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/lmeninato/GoFundMe/master/data-raw/GFM_data.csv", sep="\t")

# %% [markdown]
# # Let's explore the data file
#
# 1.   `show the first few rows of the data file.`
# 2.   List and describe the meaning of each row

# %%
df
# Out:
#       Unnamed: 0                                                Url Category  \
# 0              0  https://www.gofundme.com/3ctqm-medical-bills-f...  Medical
# 1              1  https://www.gofundme.com/olivia-stoy-bone-marr...  Medical
# 2              2  https://www.gofundme.com/autologous-Tcell-Tran...  Medical
# 3              3       https://www.gofundme.com/a-chance-of-rebirth  Medical
# 4              4                https://www.gofundme.com/teamclaire  Medical
# ...          ...                                                ...      ...
# 1237        1237  https://www.gofundme.com/help-send-michelle-to...   Wishes
# 1238        1238     https://www.gofundme.com/support-alvins-family   Wishes
# 1239        1239  https://www.gofundme.com/nuclear-medicine-tech...   Wishes
# 1240        1240  https://www.gofundme.com/girls-junior-national...   Wishes
# 1241        1241  https://www.gofundme.com/home-for-mom-with-dis...   Wishes
#
#      Position                                Title                  Location  \
# 0           0     92 Yr old Man Brutally Attacked.           LOS ANGELES, CA
# 1           0  Olivia Stoy:Transplant & Liv it up!                ASHLEY, IN
# 2           1         AUTOLOGOUS T CELL TRANSPLANT         STATEN ISLAND, NY
# 3           1                  A chance of rebirth                DUBLIN, CA
# 4           1       Claire Wineland Needs Our Help          GARDEN GROVE, CA
# ...       ...                                  ...                       ...
# 1237       22        Help Send Michelle to Israel!           DELL RAPIDS, SD
# 1238       22             Support Alvinâs Family                MONROE, GA
# 1239       23           College & Medical expenses                DALLAS, TX
# 1240       23                        Rhonda's Wish  San Antonio TX 78218, US
# 1241       23      Home for Mom with disabled kids        Pembroke Pines, FL
#
#       Amount_Raised     Goal Number_of_Donators Length_of_Fundraising  \
# 0          327345.0   15,000             12,167               1 month
# 1          316261.0     1.0M              5,598              3 months
# 2          241125.0  250,000                841              2 months
# 3          237424.0  225,000              4,708               1 month
# 4          236590.0  225,000              8,393              2 months
# ...             ...      ...                ...                   ...
# 1237        10370.0    8,000                103              5 months
# 1238        10349.0   15,000                185               1 month
# 1239        10330.0   50,000                  9               27 days
# 1240        10265.0   15,000                109              3 months
# 1241        10253.0   15,000                100              5 months
#
#      FB_Shares GFM_hearts                                               Text  \
# 0          26k        12k  Rodolfo Rodriguez needs your help today! 92 Yr...
# 1          12k       5.7k  Thomas Stoy needs your help today! Olivia Stoy...
# 2         1.8k        836  Philip Defonte needs your help today! AUTOLOGO...
# 3         9.7k       4.7k  Sriram Kanniah needs your help today! A chance...
# 4         6.4k       8.9k  Melissa Yeager needs your help today! Claire W...
# ...        ...        ...                                                ...
# 1237       398        106  Michelle Serlet needs your help today! Help Se...
# 1238       977        194  Kalvin Ahmed needs your help today! Support Al...
# 1239        66         11  Anjelica Vossler needs your help today! Colleg...
# 1240       476        114  Anesi Maverick Tuufuli needs your help today! ...
# 1241       322         94  Liseth Valencia needs your help today! Home fo...
#
#        Latitude   Longitude
# 0     34.052234 -118.243685
# 1     41.527273  -85.065523
# 2     40.579532  -74.150201
# 3     37.702152 -121.935792
# 4     33.774269 -117.937995
# ...         ...         ...
# 1237  43.826084  -96.706161
# 1238  33.794836  -83.713229
# 1239  32.776664  -96.796988
# 1240  29.489578  -98.385532
# 1241  26.007765  -80.296256
#
# [1242 rows x 15 columns]

# %%
# Going ahead and slotting this in here for later. 

def value_to_float(x):

    if type(x) == float or type(x) == int:
        return x

    if 'k' in x:
        if len(x) > 1:
            return float(x.replace('k', '')) * 1000
        return 1000.0

    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0

    if 'm' in x:
        if len(x) > 1:
            return float(x.replace('m', '')) * 1000000
        return 1000000.0

    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0

    if 'b' in x:
        return float(x.replace('b', '')) * 1000000000

    if ',' in x:
        return float(x.replace(',', ''))

    return x

# %%
df.FB_Shares = df.FB_Shares.apply(value_to_float)
df.GFM_hearts = df.GFM_hearts.apply(value_to_float)
df.Goal = df.Goal.apply(value_to_float)

df.head()
# Out:
#    Unnamed: 0                                                Url Category  \
# 0           0  https://www.gofundme.com/3ctqm-medical-bills-f...  Medical
# 1           1  https://www.gofundme.com/olivia-stoy-bone-marr...  Medical
# 2           2  https://www.gofundme.com/autologous-Tcell-Tran...  Medical
# 3           3       https://www.gofundme.com/a-chance-of-rebirth  Medical
# 4           4                https://www.gofundme.com/teamclaire  Medical
#
#   Position                                Title           Location  \
# 0        0     92 Yr old Man Brutally Attacked.    LOS ANGELES, CA
# 1        0  Olivia Stoy:Transplant & Liv it up!         ASHLEY, IN
# 2        1         AUTOLOGOUS T CELL TRANSPLANT  STATEN ISLAND, NY
# 3        1                  A chance of rebirth         DUBLIN, CA
# 4        1       Claire Wineland Needs Our Help   GARDEN GROVE, CA
#
#    Amount_Raised       Goal Number_of_Donators Length_of_Fundraising  \
# 0       327345.0    15000.0             12,167               1 month
# 1       316261.0  1000000.0              5,598              3 months
# 2       241125.0   250000.0                841              2 months
# 3       237424.0   225000.0              4,708               1 month
# 4       236590.0   225000.0              8,393              2 months
#
#   FB_Shares GFM_hearts                                               Text  \
# 0   26000.0    12000.0  Rodolfo Rodriguez needs your help today! 92 Yr...
# 1   12000.0     5700.0  Thomas Stoy needs your help today! Olivia Stoy...
# 2    1800.0        836  Philip Defonte needs your help today! AUTOLOGO...
# 3    9700.0     4700.0  Sriram Kanniah needs your help today! A chance...
# 4    6400.0     8900.0  Melissa Yeager needs your help today! Claire W...
#
#     Latitude   Longitude
# 0  34.052234 -118.243685
# 1  41.527273  -85.065523
# 2  40.579532  -74.150201
# 3  37.702152 -121.935792
# 4  33.774269 -117.937995

# %% [markdown]
# *list and description of column headers go here*

# %% [markdown]
# # Campaigns by Category
#
#
#
# 1.   `How many campaigns are in each category?`
# 2.   `What is the average $ amount raised in each category?`
# 3.   `What is the average fundraising goal in each category?`
# 4.   Provide a text summary of the results
#
# *feel free to use multiple code blocks if you'd like*

# %%
df.Category.value_counts()
# Out:
# Medical        76
# Memorial       72
# Volunteer      72
# Travel         72
# Sports         72
# Newlywed       72
# Family         72
# Faith          72
# Event          72
# Creative       72
# Competition    72
# Community      72
# Business       72
# Education      72
# Charity        72
# Emergency      72
# Wishes         72
# Animals        10
# 11525.0         1
# -73.9495823     1
# -75.3199035     1
# Name: Category, dtype: int64

# %%
df_grouped = df.groupby('Category')

# %%
for group_name, df_group in df_grouped:
  print("Mean $ Raised:", group_name, df_group["Amount_Raised"].mean())
# Out:
# Mean $ Raised: -73.9495823 nan
# Mean $ Raised: -75.3199035 nan
# Mean $ Raised: 11525.0 688.0
# Mean $ Raised: Animals 98085.4
# Mean $ Raised: Business 11813.430555555555
# Mean $ Raised: Charity 65931.91666666667
# Mean $ Raised: Community 120226.7042253521
# Mean $ Raised: Competition 5570.375
# Mean $ Raised: Creative 25302.347222222223
# Mean $ Raised: Education 45777.86111111111
# Mean $ Raised: Emergency 116201.01388888889
# Mean $ Raised: Event 10978.422535211268
# Mean $ Raised: Faith 12903.785714285714
# Mean $ Raised: Family 63499.86111111111
# Mean $ Raised: Medical 147340.40789473685
# Mean $ Raised: Memorial 115498.94444444444
# Mean $ Raised: Newlywed 3478.8169014084506
# Mean $ Raised: Sports 19540.125
# Mean $ Raised: Travel 7099.871428571429
# Mean $ Raised: Volunteer 13642.472222222223
# Mean $ Raised: Wishes 23230.583333333332

# %%
for group_name, df_group in df_grouped:
  print("Mean Goal:", group_name, df_group["Goal"].mean())
# Out:
# Mean Goal: -73.9495823 nan
# Mean Goal: -75.3199035 nan
# Mean Goal: 11525.0 141.0
# Mean Goal: Animals 98500.0
# Mean Goal: Business 36416.208333333336
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-e269889f5681> in <module>()
#       1 for group_name, df_group in df_grouped:
# ----> 2   print("Mean Goal:", group_name, df_group["Goal"].mean())
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#   10372
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10353             )
#   10354         return self._reduce(
# > 10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#   10357
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# *summarize output here*

# %% [markdown]
# # Looking for outliers in shares and hearts
#
#
#
# 1.   `Select 3 catgories and create a boxplot of the FB shares and GFM hearts`
# 2.   `Plot the outliers in the boxplot`
# 1.   `Calculate the mean, median, mode, std deviation, and variance for the 3 categories' FB shares and GFM hearts`
# 3.   Summarize these results. What conclusions can you come to about these results?

# %%
df_medical = df_grouped.get_group('Medical')

fig = px.box(df_medical, x = "FB_Shares", title = "Distribution of FB Shares")
fig.show()

fig = px.box(df_medical, x = "GFM_hearts", title = "Distribution of GFM Hearts")
fig.show()

print("Mean :", df_medical["FB_Shares"].mean(skipna=True, numeric_only=None))
print("Median:", df_medical["FB_Shares"].median())
print("Mode of:", df_medical["FB_Shares"].mode())
print("Variance: ",df_medical["FB_Shares"].var())
print("Standard Deviation: ", df_medical["FB_Shares"].std())

print("Mean :", df_medical["GFM_hearts"].mean(skipna=True, numeric_only=None))
print("Median:", df_medical["GFM_hearts"].median())
print("Mode of:", df_medical["GFM_hearts"].mode())
print("Variance: ",df_medical["GFM_hearts"].var())
print("Standard Deviation: ", df_medical["GFM_hearts"].std())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="81e7e047-96e3-4f08-a5e5-3b8c910200eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81e7e047-96e3-4f08-a5e5-3b8c910200eb")) {                    Plotly.newPlot(                        "81e7e047-96e3-4f08-a5e5-3b8c910200eb",                        [{"alignmentgroup":"True","hovertemplate":"FB_Shares=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[26000.0,12000.0,1800.0,9700.0,6400.0,3700.0,10000.0,2800.0,3300.0,6000.0,3200.0,1300.0,2500.0,5600.0,"606",12000.0,2400.0,2100.0,1600.0,8600.0,1000.0,1800.0,9900.0,1600.0,9100.0,1600.0,1600.0,2600.0,8500.0,3800.0,"845",2000.0,7400.0,"913","246",11000.0,2300.0,3100.0,2300.0,"365",8700.0,1700.0,"764","921","904",5100.0,9400.0,1300.0,11000.0,"828","723",12000.0,9100.0,3000.0,3100.0,2400.0,2500.0,1000.0,"681","147",1800.0,1700.0,1100.0,1600.0,"170",2600.0,1300.0,1500.0,2000.0,"689",9200.0,"330",1300.0,2300.0,1300.0,8700.0],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.666666666 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9338550f-f9dd-4087-9851-6f55ff919ec8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9338550f-f9dd-4087-9851-6f55ff919ec8")) {                    Plotly.newPlot(                        "9338550f-f9dd-4087-9851-6f55ff919ec8",                        [{"alignmentgroup":"True","hovertemplate":"GFM_hearts=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[12000.0,5700.0,"836",4700.0,8900.0,2700.0,2700.0,"949",2000.0,2500.0,"932","597","859",1500.0,2700.0,5300.0,1100.0,2800.0,1400.0,1600.0,1100.0,"813",1900.0,"785",2200.0,"612","691",2400.0,1200.0,"944","627",3200.0,"925","648","295",2500.0,"885",1100.0,1100.0,"364",1000.0,"770","584",1500.0,1300.0,2700.0,1700.0,"649",1900.0,"645",1000.0,2200.0,1400.0,1100.0,1900.0,"954",1300.0,"549","245","367","608","832","524","707","106",1100.0,"614",1100.0,"975","722",1800.0,2400.0,"598","886","599",1000.0],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-6cbfad446506> in <module>()
#       7 fig.show()
#       8
# ----> 9 print("Mean :", df_medical["FB_Shares"].mean(skipna=True, numeric_only=None))
#      10 print("Median:", df_medical["FB_Shares"].median())
#      11 print("Mode of:", df_medical["FB_Shares"].mode())
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#   10372
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10353             )
#   10354         return self._reduce(
# > 10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#   10357
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
print("Variance: ",df_medical["FB_Shares"].var())
print("Standard Deviation: ", df_medical["FB_Shares"].std())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-116df947da68> in <module>()
# ----> 1 print("Variance: ",df_medical["FB_Shares"].var())
#       2 print("Standard Deviation: ", df_medical["FB_Shares"].std())
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in var(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   10604             **kwargs,
#   10605         ):
# > 10606             return NDFrame.var(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   10607
#   10608         setattr(cls, "var", var)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in var(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   10312     ):
#   10313         return self._stat_function_ddof(
# > 10314             "var", nanops.nanvar, axis, skipna, level, ddof, numeric_only, **kwargs
#   10315         )
#   10316
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _stat_function_ddof(self, name, func, axis, skipna, level, ddof, numeric_only, **kwargs)
#   10298             )
#   10299         return self._reduce(
# > 10300             func, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   10301         )
#   10302
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanvar(values, axis, skipna, ddof, mask)
#     931     if axis is not None:
#     932         avg = np.expand_dims(avg, axis)
# --> 933     sqr = _ensure_numeric((avg - values) ** 2)
#     934     if mask is not None:
#     935         np.putmask(sqr, mask, 0)
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'

# %%
df_emergency = df_grouped.get_group('Emergency')

fig = px.box(df_emergency , x = "FB_Shares", title = "Distribution of FB Shares")
fig.show()

fig = px.box(df_emergency , x = "GFM_hearts", title = "Distribution of GFM Hearts")
fig.show()

print("Mean :", df_emergency ["FB_Shares"].mean(skipna=True, numeric_only=None))
print("Median:", df_emergency["FB_Shares"].median())
print("Mode of:", df_emergency ["FB_Shares"].mode())
print("Variance: ",df_emergency["FB_Shares"].var())
print("Standard Deviation: ", df_emergency["FB_Shares"].std())

print("Mean :", df_emergency ["GFM_hearts"].mean(skipna=True, numeric_only=None))
print("Median:", df_emergency["GFM_hearts"].median())
print("Mode of:", df_emergency ["GFM_hearts"].mode())
print("Variance: ",df_emergency["GFM_hearts"].var())
print("Standard Deviation: ", df_emergency["GFM_hearts"].std())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bccfbfbc-1133-4a5f-b602-96e6df149c51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bccfbfbc-1133-4a5f-b602-96e6df149c51")) {                    Plotly.newPlot(                        "bccfbfbc-1133-4a5f-b602-96e6df149c51",                        [{"alignmentgroup":"True","hovertemplate":"FB_Shares=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[6400.0,5400.0,20000.0,5100.0,8800.0,15000.0,16000.0,5200.0,5700.0,2700.0,8500.0,7800.0,2600.0,1400.0,3600.0,1900.0,3100.0,11000.0,3600.0,2400.0,3000.0,5800.0,5300.0,5300.0,4800.0,1100.0,3600.0,5300.0,8700.0,1100.0,8400.0,2600.0,1000.0,2100.0,3900.0,1800.0,1900.0,1000.0,12000.0,8300.0,8400.0,2700.0,2500.0,3800.0,4400.0,1600.0,2200.0,"894",2300.0,2900.0,"499",3900.0,"825","816",2100.0,5100.0,4500.0,1100.0,6100.0,2000.0,4800.0,"961",1600.0,1300.0,1400.0,1900.0,2100.0,3100.0,1200.0,"736",1800.0,"652"],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0. ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7cee7066-38b3-49ce-8f7a-56e407bf2d79" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cee7066-38b3-49ce-8f7a-56e407bf2d79")) {                    Plotly.newPlot(                        "7cee7066-38b3-49ce-8f7a-56e407bf2d79",                        [{"alignmentgroup":"True","hovertemplate":"GFM_hearts=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[2300.0,2500.0,3100.0,1100.0,5600.0,5100.0,2400.0,2200.0,2000.0,3400.0,5900.0,2500.0,"513",3300.0,1000.0,2000.0,1500.0,2400.0,"764",1000.0,2700.0,1600.0,1200.0,"896",1900.0,"378",1200.0,1300.0,1000.0,1000.0,3400.0,"652","335",1800.0,"825","794","627",2000.0,2700.0,2100.0,1700.0,"777","904","790","669","608","491","467",2400.0,1000.0,"556","833","595","720","896","936",1200.0,"612",1000.0,"759",1500.0,"592",2100.0,"654","231","495",1600.0,"390","529","238","865","535"],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-42815237cd2e> in <module>()
#       7 fig.show()
#       8
# ----> 9 print("Mean :", df_emergency ["FB_Shares"].mean(skipna=True, numeric_only=None))
#      10 print("Median:", df_emergency["FB_Shares"].median())
#      11 print("Mode of:", df_emergency ["FB_Shares"].mode())
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#   10372
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10353             )
#   10354         return self._reduce(
# > 10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#   10357
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
df_memorial = df_grouped.get_group('Memorial')

fig = px.box(df_memorial , x = "FB_Shares", title = "Distribution of FB Shares")
fig.show()

fig = px.box(df_memorial , x = "GFM_hearts", title = "Distribution of GFM Hearts")
fig.show()

print("Mean :", df_memorial ["FB_Shares"].mean(skipna=True, numeric_only=None))
print("Median:", df_memorial ["FB_Shares"].median())
print("Mode of:", df_memorial ["FB_Shares"].mode())
print("Variance: ",df_memorial["FB_Shares"].var())
print("Standard Deviation: ", df_memorial["FB_Shares"].std())

print("Mean :", df_memorial ["GFM_hearts"].mean(skipna=True, numeric_only=None))
print("Median:", df_memorial ["GFM_hearts"].median())
print("Mode of:", df_memorial ["GFM_hearts"].mode())
print("Variance: ",df_memorial["GFM_hearts"].var())
print("Standard Deviation: ", df_memorial["GFM_hearts"].std())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c657e59c-e3f2-4bcd-93cc-3a964e39abae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c657e59c-e3f2-4bcd-93cc-3a964e39abae")) {                    Plotly.newPlot(                        "c657e59c-e3f2-4bcd-93cc-3a964e39abae",                        [{"alignmentgroup":"True","hovertemplate":"FB_Shares=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[10000.0,47000.0,29000.0,3100.0,63000.0,22000.0,12000.0,3300.0,1000.0,4200.0,2000.0,11000.0,6400.0,5700.0,11000.0,5400.0,"95",3700.0,1900.0,1600.0,5500.0,2900.0,1300.0,4500.0,5000.0,9000.0,3800.0,2900.0,26000.0,6500.0,"811","579","786","605",1300.0,"381",8800.0,"831","545",5800.0,"918",3400.0,3400.0,"840",14000.0,3900.0,2400.0,"536","750",1600.0,2400.0,4400.0,"623",1300.0,6300.0,2000.0,"996",7200.0,1300.0,"487",8300.0,"833",4300.0,3300.0,"909",5900.0,2400.0,1300.0,3800.0,"972","699",3200.0],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="13493cd4-8f45-45c2-962f-1751a886c694" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13493cd4-8f45-45c2-962f-1751a886c694")) {                    Plotly.newPlot(                        "13493cd4-8f45-45c2-962f-1751a886c694",                        [{"alignmentgroup":"True","hovertemplate":"GFM_hearts=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[5900.0,16000.0,5100.0,10000.0,8100.0,3600.0,2200.0,1100.0,"606",1500.0,1200.0,2200.0,1900.0,1600.0,2400.0,1400.0,"316","656","676","389",2100.0,1200.0,"923","955",1300.0,1000.0,1000.0,1000.0,2300.0,1500.0,"970","318","482",1000.0,"384","612",1400.0,1700.0,"305",1400.0,"291","629",6500.0,"613",1400.0,1700.0,"563","937","577",1600.0,"908","900","689","458",1000.0,"569","354",1000.0,"532","570","983","330",2100.0,"995","268",1000.0,"511","517","917","289","656","740"],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8 ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-6c952aa40587> in <module>()
#       7 fig.show()
#       8
# ----> 9 print("Mean :", df_memorial ["FB_Shares"].mean(skipna=True, numeric_only=None))
#      10 print("Median:", df_memorial ["FB_Shares"].median())
#      11 print("Mode of:", df_memorial ["FB_Shares"].mode())
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10749         )
#   10750         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 10751             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10752
#   10753         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10368     def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
#   10369         return self._stat_function(
# > 10370             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10371         )
#   10372
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10353             )
#   10354         return self._reduce(
# > 10355             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10356         )
#   10357
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      92             try:
#      93                 with np.errstate(invalid="ignore"):
# ---> 94                     return f(*args, **kwargs)
#      95             except ValueError as e:
#      96                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     154                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     155             else:
# --> 156                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157
#     158             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     409             mask = isna(values)
#     410
# --> 411         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     412
#     413         if datetimelike:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     664
#     665     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 666     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     667
#     668     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      49
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
df_memorial.GFM_hearts.describe()
# Out:
# count       72.0
# unique      56.0
# top       1000.0
# freq         7.0
# Name: GFM_hearts, dtype: float64

# %% [markdown]
# *summarize your outlier results here*

# %% [markdown]
# # Explore on your own
#
# 1. Select one category and use descriptive stats to explore the success of campaigns in this category.
# 1. Use graphs where approporiate.
# 1. Provide commentary aling the way on what descriptive measures you are using and why.
# 1. Provide a one to two paragraph summary of the success of this category.
#
# *use as many code and text blocks along the way*
# *Also make sure to consult the pandas and plotly documentation along the way*
